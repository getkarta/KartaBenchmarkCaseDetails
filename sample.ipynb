# %%
from karta_benchmarks.namespaces.domains import Domains
from karta_benchmarks.context_engine import ContextEngine
## Create the context engine
context_engine = ContextEngine(domain=Domains.ECOMMERCE)
# Out:
# ======== Created Context Engine for ecommerce ========

# %%
context_engine.artifacts["func"]()
# Out:
# {'items': {'ITM001234': {'item_description': 'Sound Blaster Head Phones Pro',
#    'item_weight': 0.2,
#    'item_cost': 4256.32,
#    'seller_id': 'SELL7786',
#    'restricted_zip_codes': [],
#    'item_category': 'Electronics',
#    'item_specifications': [{'property_name': 'Color',
#      'property_value': 'Black'},
#     {'property_name': 'Brand', 'property_value': 'Sound Blaster'},
#     {'property_name': 'Connectivity', 'property_value': 'Wireless'}]},
#   'ITM001235': {'item_description': 'Mechanical Keyboard X200',
#    'item_weight': 1.1,
#    'item_cost': 7899.99,
#    'seller_id': 'SELL1234',
#    'restricted_zip_codes': [],
#    'item_category': 'Electronics',
#    'item_specifications': [{'property_name': 'Color',
#      'property_value': 'White'},
#     {'property_name': 'Brand', 'property_value': 'KeyMaster'},
#     {'property_name': 'Switch Type', 'property_value': 'Mechanical'},
#     {'property_name': 'Connectivity', 'property_value': 'Wired'}]},
#   'ITM001236': {'item_description': 'Modern Dining Table Set',
#    'item_weight': 50.0,
#    'item_cost': 15999.99,
#    'seller_id': 'SELL5678',
#    'restricted_zip_codes': ['543221', '987652'],
#    'item_category': 'Home Goods',
#    'item_specifications': [{'property_name': 'Color',
#      'property_value': 'Brown'},
#     {'property_name': 'Material', 'property_value': 'Wood'},
#     {'property_name': 'Seating Capacity', 'property_value': '6'},
#     {'property_name': 'Shape', 'property_value': 'Rectangular'}]},
#   'ITM001237': {'item_description': 'Lenovo ThinkPad Laptop',
#    'item_weight': 1.4,
#    'item_cost': 40000.99,
#    'seller_id': 'SELL1234',
#    'restricted_zip_codes': [],
#    'item_category': 'Electronics - Laptop',
#    'item_specifications': [{'property_name': 'Color',
#      'property_value': 'Black'},
#     {'property_name': 'Brand', 'property_value': 'Lenovo'},
#     {'property_name': 'Processor', 'property_value': 'Intel Core i5'},
#     {'property_name': 'RAM', 'property_value': '16GB'}]},
#   'ITM001238': {'item_description': 'Robonics Mouse Pad',
#    'item_weight': 0.1,
#    'item_cost': 199.99,
#    'seller_id': 'SELL1234',
#    'restricted_zip_codes': [],
#    'item_category': 'Electronics - Accessories',
#    'item_specifications': [{'property_name': 'Color',
#      'property_value': 'Black'}]}},
#  'orders': {'ORD001998': {'order_id': 'ORD001998',
#    'customer_id': 'CUST001001',
#    'order_date': '2024-05-17',
#    'shipping_address': {'address_1': '123 Main St',
#     'address_2': 'Apt 4B',
#     'address_3': 'Unit 101',
#     'postal_code': '12345',
#     'contact_number': '+91 99999 88888'},
#    'payment_status': 'SUCCESS',
#    'items_ordered': [{'item_number': 'ITM001234',
#      'qty': 1,
#      'promised_delivery_date': '2024-05-24',
#      'item_original_cost': 4256.32,
#      'applied_discount': 0.0,
#      'item_final_cost': 4256.32,
#      'package_id': 'PACK00789812'}],
#    'payment_method': [{'payment_method_id': 'PM001234',
#      'type': 'CREDIT_CARD',
#      'amount_paid': 4256.32}]},
#   'ORD202405231': {'order_id': 'ORD202405231',
#    'customer_id': 'CUST001004',
#    'order_date': '2024-05-23',
#    'shipping_address': {'address_1': '123 Main St',
#     'address_2': 'Apt 5B',
#     'address_3': 'Unit 109',
#     'postal_code': '77612',
#     'contact_number': '+91 99991 88888'},
#    'payment_status': 'FAILED',
#    'items_ordered': [{'item_number': 'ITM001237',
#      'qty': 1,
#      'promised_delivery_date': '2024-05-30',
#      'item_original_cost': 40000.99,
#      'applied_discount': 0.0,
#      'item_final_cost': 40000.99,
#      'package_id': ''}],
#    'payment_method': [{'payment_method_id': 'PM001237',
#      'type': 'CREDIT_CARD',
#      'amount_paid': 40000.99}]},
#   'ORD202405232': {'order_id': 'ORD202405232',
#    'customer_id': 'CUST001004',
#    'order_date': '2024-05-23',
#    'shipping_address': {'address_1': '123 Main St',
#     'address_2': 'Apt 5B',
#     'address_3': 'Unit 109',
#     'postal_code': '77612',
#     'contact_number': '+91 99991 88888'},
#    'payment_status': 'SUCCESS',
#    'items_ordered': [{'item_number': 'ITM001238',
#      'qty': 1,
#      'promised_delivery_date': '2024-05-28',
#      'item_original_cost': 199.99,
#      'applied_discount': 0.0,
#      'item_final_cost': 199.99,
#      'package_id': ''}],
#    'payment_method': [{'payment_method_id': 'PM001238',
#      'type': 'CREDIT_CARD',
#      'amount_paid': 199.99}]}},
#  'customers': {'CUST001001': {'customer_id': 'CUST001001',
#    'is_rewards_and_benfits_member': False,
#    'first_name': 'Rahul',
#    'last_name': 'Gupta',
#    'email': 'rahulgupta@example.com',
#    'phone_number': '+91 99999 88888',
#    'date_of_birth': '1994-01-01',
#    'gender': 'Male',
#    'account_creation_date': '2023-12-22',
#    'last_order_date': '2024-05-17',
#    'is_active': True,
#    'is_email_verified': True,
#    'is_phone_verified': True,
#    'is_fraud_flag': False,
#    'active_orders': ['ORD001998'],
#    'active_returns': []},
#   'CUST0001004': {'customer_id': 'CUST001004',
#    'is_rewards_and_benfits_member': True,
#    'first_name': 'Riddhima',
#    'last_name': 'Khan',
#    'email': 'riddhi@example.com',
#    'phone_number': '+91 99991 88888',
#    'date_of_birth': '1990-03-01',
#    'gender': 'Female',
#    'account_creation_date': '2022-01-21',
#    'last_order_date': '2024-05-23',
#    'is_active': True,
#    'is_email_verified': True,
#    'is_phone_verified': True,
#    'is_fraud_flag': False,
#    'active_orders': ['ORD202405231', 'ORD202405232'],
#    'active_returns': []}},
#  'payment_methods': {'PM0001234': {'customer_id': 'CUST001001',
#    'payment_method_type': 'CREDIT_CARD',
#    'expiry_date': '2040-03-20',
#    'billing_address': {'address_1': '123 Main St',
#     'address_2': 'Apt 4B',
#     'address_3': 'Unit 101',
#     'postal_code': '12345'},
#    'identification_number': 'XXXX XXXX XXXX 3456'},
#   'PM001237': {'customer_id': 'CUST001004',
#    'payment_method_type': 'CREDIT_CARD',
#    'expiry_date': '2039-03-20',
#    'billing_address': {'address_1': '123 Main St',
#     'address_2': 'Apt 5B',
#     'address_3': 'Unit 101',
#     'postal_code': '77612'},
#    'identification_number': 'XXXX XXXX XXXX 0009'}},
#  'packages': {'PACK00789812': {'destination_address': {'address_1': '123 Main St',
#     'address_2': 'Apt 4B',
#     'address_3': 'Unit 101',
#     'postal_code': '12345',
#     'contact_number': '+91 99999 88888'},
#    'shipper_name': 'FastCargo',
#    'estimated_delivery_date': '2024-05-27 10:00:00',
#    'shipment_cost': 120,
#    'origin_code': 'DEL',
#    'current_status': 'IN_TRANSIT',
#    'tracking_details': {'2024-05-19 10:00:00': {'event': 'DESPATCHED',
#      'location_type': 'WAREHOUSE'},
#     '2024-05-20 10:00:00': {'event': 'RECEIVED',
#      'location_type': 'COURIER FACILITY'},
#     '2024-05-22 17:00:00': {'event': 'DESPATCHED',
#      'location_type': 'COURIER FACILITY'}}}},
#  'contacts': {}}
